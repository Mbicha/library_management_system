# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("books.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5557 entries, 0 to 5556
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          5557 non-null   int64
#  1   bk_title        5557 non-null   object
#  2   bk_authors      5557 non-null   object
#  3   categories      5474 non-null   object
#  4   thumbnail       5284 non-null   object
#  5   description     5347 non-null   object
#  6   published_year  5557 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 304.0+ KB

# %%
df.columns
# Out:
# Index(['isbn13', 'bk_title', 'bk_authors', 'categories', 'thumbnail',
#        'description', 'published_year'],
#       dtype='object')

# %%
book_df = df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# isbn13            0
# bk_title          0
# bk_authors        0
# categories        0
# thumbnail         0
# description       0
# published_year    0
# dtype: int64

# %%
# %%timeit -n 1000
# Numpy vectorization
# isbn = df['isbn13'].to_numpy().tolist()
# title = df['bk_title'].to_numpy().tolist()
bk = df[['bk_title','bk_authors', 'categories']].to_numpy().tolist()

# %%
for book in bk:
    print(book)
# Out:
# ['Gilead', 'Marilynne Robinson', 'Fiction']
# ['The One Tree', 'Stephen R. Donaldson', 'American fiction']
# ['Rage of angels', 'Sidney Sheldon', 'Fiction']
# ['The Four Loves', 'Clive Staples Lewis', 'Christian life']
# ['The Problem of Pain', 'Clive Staples Lewis', 'Christian life']
# ['An Autobiography', 'Agatha Christie', 'Authors, English']
# ['Empires of the Monsoon', 'Richard Hall', 'Africa, East']
# ['The Gap Into Madness', 'Stephen R. Donaldson', 'Hyland, Morn (Fictitious character)']
# ['Master of the Game', 'Sidney Sheldon', 'Adventure stories']
# ['If Tomorrow Comes', 'Sidney Sheldon', 'Adventure stories']
# ["Assassin's Apprentice", 'Robin Hobb', 'American fiction']
# ['Warhost of Vastmark', 'Janny Wurts', 'Fiction']
# ['The Once and Future King', 'Terence Hanbury White', 'Arthurian romances']
# ['Witness for the Prosecution & Selected Plays', 'Agatha Christie', 'English drama']
# ['The Little House', 'Philippa Gregory', 'Country life']
# ...
